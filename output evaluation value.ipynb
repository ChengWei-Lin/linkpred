# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Use following algorithms
# 1. [jaccard](https://networkx.github.io/documentation/networkx-1.9/reference/generated/networkx.algorithms.link_prediction.jaccard_coefficient.html)
# 2. [adamic adar](https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.algorithms.link_prediction.adamic_adar_index.html)
# 3. [preferential attachment](https://networkx.github.io/documentation/stable/reference/algorithms/generated/networkx.algorithms.link_prediction.preferential_attachment.html#networkx.algorithms.link_prediction.preferential_attachment)
# 4. [katz](https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.algorithms.centrality.katz_centrality.html) (and try different beta, maybe max_power)
#
#     4.1 small beta value (float), will find it more similar to CommonNeighbor algo, which doesn't consider other nodes other than neighbors
#     4.2 max_power (int), which means to what extent of path length will be considered
#
# We want this for output
# * P is whether Katz value exceed the threshold
#
#                 Katz,   P,    TP,    normalized betweenness of the whole graph
#         A, B    0.05,   1,    1,
#         C, D    0.07,   1,    0,
#         E, F    0.10,   0,    0,
#
# # How we find the best threshold
# To find the best sensitivity and specificity, we use
# [YoudenIndex](https://en.wikipedia.org/wiki/Youden%27s_J_statistic?fbclid=IwAR3OICm3oJQQnopIKeflrpd1K-DcxahLE9IerxPfb8k6uISWt30D4DexuCA)
#
#     J = sensitivity + specificity - 1
#     sensitivity = tp / tp + fn (ALL YES)
#     specificity = tn / fp + tn (ALL NO )
#
# ## sensitivity and specificity
# [wikipedia](https://en.wikipedia.org/wiki/Sensitivity_and_specificity)

# %%
import os
import pandas as pd
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

journal = input('scientometrics / jasist')
entity = input('co-author / co-occurrence')

path = os.getcwd()
all_eva_files = []
a1_eva_files, a2_eva_files, a3_eva_files = [], [], []
evaluation_result_path = path+"\\data_transformation_output\\{}\\netfiles\\{}\\".format(journal, entity)
for f in os.listdir(evaluation_result_path):
    if f.endswith(".txt"):
        all_eva_files.append(evaluation_result_path+f)
        if 'Jaccard' in f:
            a1_eva_files.append(evaluation_result_path+f)
        elif 'Katz_beta001' in f:
            a2_eva_files.append(evaluation_result_path+f)
        elif 'AdamicAdar' in f:
            a3_eva_files.append(evaluation_result_path+f)
all_a_eva_files = [a1_eva_files, a2_eva_files, a3_eva_files]
# Out:
# scientometrics / jasistscientometrics
# co-author / co-occurrenceco-occurrence

# %% [markdown]
# ### netfiles

# %%
netfiles_path = path+"\\data_transformation_output\\{}\\netfiles\\{}\\".format(journal, entity)
netfiles = []
for f in os.listdir(netfiles_path):
    if f.endswith('.net'):
        netfiles.append(netfiles_path+f)

netfiles
# Out:
# ['C:\\Users\\Liser\\Desktop\\linchengwei_link_prediction\\data_transformation_output\\scientometrics\\netfiles\\co-occurrence\\2010-15.net',
#  'C:\\Users\\Liser\\Desktop\\linchengwei_link_prediction\\data_transformation_output\\scientometrics\\netfiles\\co-occurrence\\2016-16.net',
#  'C:\\Users\\Liser\\Desktop\\linchengwei_link_prediction\\data_transformation_output\\scientometrics\\netfiles\\co-occurrence\\2016-17.net',
#  'C:\\Users\\Liser\\Desktop\\linchengwei_link_prediction\\data_transformation_output\\scientometrics\\netfiles\\co-occurrence\\2016-18.net',
#  'C:\\Users\\Liser\\Desktop\\linchengwei_link_prediction\\data_transformation_output\\scientometrics\\netfiles\\co-occurrence\\2016-19.net']

# %% [markdown]
# ### start

# %%
import linkpred
# from matplotlib import pyplot as plt
training_file = netfiles[0]
testing_file = netfiles[1]

# Read network
G = linkpred.read_network(training_file)

# read test network
test = linkpred.read_network(testing_file)

# Exclude test network from learning phase
training = G.copy()
# training.remove_edges_from(test.edges())

# jaccard = linkpred.predictors.Jaccard(training, excluded=training.edges()) #, excluded=training.edges()
# jaccard_results = jaccard.predict()

# test_set = set(linkpred.evaluation.Pair(u, v) for u, v in test.edges())
# evaluation = linkpred.evaluation.EvaluationSheet(jaccard_results, test_set)
# Out:
# Network contains multiple edges. These will be ignored.
# Network contains multiple edges. These will be ignored.

# %% [markdown]
# # Computing Edge Betweenness in full testing network

# %%
import networkx as nx
edge_betweenness_result = nx.algorithms.centrality.edge_betweenness_centrality(test)

# %%
len(edge_betweenness_result)
# Out:
# 3772

# %%
for kw, score in edge_betweenness_result.items():
     print(kw, score)
# Out:
# ('"All-in-one" indicator', 'Altmetric score') 1.3382348414793919e-06
# ('"All-in-one" indicator', 'Altmetrics') 0.0013435877808453095
# ('1 Nano enabled drug delivery', 'Bibliography analysis') 1.3382348414793919e-06
# ('1 Nano enabled drug delivery', 'Graphene') 6.691174207396959e-06
# ('1 Nano enabled drug delivery', 'Specialization score') 1.3382348414793919e-06
# ('1 Nano enabled drug delivery', 'Interdisciplinarity') 0.0013342201369549538
# ('1 Nano enabled drug delivery', 'Innovation trajectory') 1.3382348414793919e-06
# ('AIC', 'Discretised lognormal') 0.0013395730763208712
# ('AIC', 'Citation counts') 1.3382348414793919e-06
# ('AIC', 'Stopped sum models') 1.3382348414793919e-06
# ('AIC', 'Negative binomial') 1.3382348414793919e-06
# ('AIC', 'Standard error') 1.3382348414793919e-06
# ('ANVUR', 'Research evaluation') 0.00023240714763335496
# ('ANVUR', 'Impact factor') 0.0002493787365156624
# ('ANVUR', 'Bibliometrics') 0.000863140131537771
# ('ARWU', 'Global university rankings') 1.3382348414793919e-06
# ('ARWU', 'World-class university') 1.3382348414793919e-06
# ('ARWU', 'USNWR') 1.3382348414793919e-06
# ('ARWU', 'Correlation') 0.0013355583717964332
# ('ARWU', 'QS') 1.3382348414793919e-06
# ('ARWU', 'URAP') 1.3382348414793919e-06
# ('ARWU', 'NTU') 1.3382348414793919e-06
# ('ARWU', 'THE') 1.3382348414793919e-06
# ('Abstracts', 'Readability') 9.367643890355742e-06
# ('Abstracts', 'Information science') 1.3382348414793919e-06
# ('Abstracts', 'Articles') 0.00028870389556954215
# ('Abstracts', 'Citations') 0.0010455162413854136
# ('Academic administration', 'Research output') 0.0013395730763208712
# ('Academic administration', 'Academic researchers') 1.3382348414793919e-06
# ('Academic administration', "Researchers' time use") 1.3382348414793919e-06
# ('Academic administration', 'Education') 1.3382348414793919e-06
# ('Academic administration', 'Multi-tasking') 1.3382348414793919e-06
# ('Academic article', 'Action research') 1.3382348414793919e-06
# ('Academic article', 'Scientific article') 1.3382348414793919e-06
# ('Academic article', 'H-index') 0.0013382348414793918
# ('Academic article', 'D-index') 1.3382348414793919e-06
# ('Academic article', 'Article download') 1.3382348414793919e-06
# ('Academic article', 'Regional repository') 1.3382348414793919e-06
# ('Academic careers', 'Gender bias') 1.3382348414793919e-06
# ('Academic careers', 'Longitudinal study') 0.00134224954600383
# ('Academic careers', 'Performance differences') 1.3382348414793919e-06
# ('Academic collaboration', 'Research institutions') 0.00045045465151821756
# ('Academic collaboration', 'Business schools rankings') 1.3382348414793919e-06
# ('Academic collaboration', 'University policy') 0.0008917948944856142
# ('Academic collaboration', 'Science indicators') 1.3382348414793919e-06
# ('Academic journal', 'Journal growth') 0.0013409113111623506
# ('Academic journal', 'Journal development') 0.0013409113111623506
# ('Academic journal', 'Academic science') 0.0013409113111623506
# ('Academic journal', 'Rational authors') 6.691174207396959e-06
# ('Academic journal', 'Manuscripts') 6.691174207396959e-06
# ('Academic journal', 'Overconfidence') 2.0073522622190877e-05
# ('Academic journal', 'Peer review') 0.006651027162152577
# ('Academic journal', 'Self-serving bias') 6.691174207396959e-06
# ('Academic journal', 'Learning') 6.691174207396959e-06
# ('Academic journal', 'Scholarly journal') 0.0013409113111623506
# ('Academic journals rankings', 'Free Disposal Hull') 1.3382348414793919e-06
# ('Academic journals rankings', 'Citation analysis') 0.0013435877808453095
# ('Academic libraries', 'Value') 1.3382348414793919e-06
# ('Academic libraries', 'Scholarly journals') 1.3382348414793919e-06
# ('Academic libraries', 'e-Journals') 1.3382348414793919e-06
# ('Academic libraries', 'Impact') 0.0004810520587133313
# ('Academic libraries', 'Publication') 1.3382348414793919e-06
# ('Academic libraries', 'Articles') 0.00013046993094026203
# ('Academic libraries', 'France') 1.3382348414793919e-06
# ('Academic libraries', 'Research outcomes') 1.3382348414793919e-06
# ('Academic libraries', 'Downloads') 1.3382348414793919e-06
# ('Academic libraries', 'h-Index') 5.382811955311062e-05
# ('Academic libraries', 'Bibliometry') 4.014704524438176e-06
# ('Academic libraries', 'Citations') 0.0006648553232238167
# ('Academic libraries', 'ScienceDirect') 1.3382348414793919e-06
# ('Academic outcomes', 'Interfield comparison') 1.3382348414793919e-06
# ('Academic outcomes', 'Alphabetization') 1.3382348414793919e-06
# ('Academic progression', 'Acceptance') 1.3382348414793919e-06
# ('Academic progression', 'Ecology') 1.3382348414793919e-06
# ('Academic progression', 'Scientific publication') 0.0013395730763208712
# ('Academic progression', 'Affecting variables') 1.3382348414793919e-06
# ('Academic progression', 'Publishing process') 1.3382348414793919e-06
# ('Academic rankings', 'Bibliometric analysis') 0.00042591520427675037
# ('Academic rankings', 'Monte Carlo simulations') 1.3382348414793919e-06
# ('Academic rankings', 'Bibliometrics') 0.0009176725765685602
# ('Academic research', 'Ph.D. training') 1.3382348414793919e-06
# ('Academic research', 'Academic training') 1.3382348414793919e-06
# ('Academic research', 'Inequality') 6.86623338021191e-05
# ('Academic research', 'Funding') 0.0007112756519977548
# ('Academic research', 'STEM') 1.3382348414793919e-06
# ('Academic research', 'Higher education') 0.0005582968556795182
# ('Academic research', 'Science policy') 1.3382348414793919e-06
# ('Academic research', 'Dissertation') 1.3382348414793919e-06
# ('Academic researchers', 'Research output') 0.0013395730763208712
# ('Academic researchers', 'Education') 1.3382348414793919e-06
# ('Academic researchers', 'Multi-tasking') 1.3382348414793919e-06
# ('Academic researchers', "Researchers' time use") 1.3382348414793919e-06
# ('Academic science', 'Journal growth') 1.3382348414793919e-06
# ('Academic science', 'Journal development') 1.3382348414793919e-06
# ('Academic science', 'Scholarly journal') 1.3382348414793919e-06
# ('Academic search engines', 'Growth of science') 0.00015343531277893494
# ('Academic search engines', 'Half-life indicator') 1.3382348414793919e-06
# ('Academic search engines', 'Google Scholar') 0.0010458307997093393
# ('Academic search engines', 'Journal Citation Reports') 0.00014298343351555574
# ('Academic search engines', 'Science obsolescence') 1.3382348414793919e-06
# ('Academic social networks', 'Open access') 0.00134224954600383
# ('Academic social networks', 'Information systems') 1.3382348414793919e-06
# ('Academic social networks', 'Copyright') 1.3382348414793919e-06
# ('Academic training', 'Ph.D. training') 1.3382348414793919e-06
# ('Academic training', 'Inequality') 6.86623338021191e-05
# ('Academic training', 'Funding') 0.0007112756519977547
# ('Academic training', 'STEM') 1.3382348414793919e-06
# ('Academic training', 'Higher education') 0.0005582968556795182
# ('Academic training', 'Science policy') 1.3382348414793919e-06
# ('Academic training', 'Dissertation') 1.3382348414793919e-06
# ('Academic writing', 'Readability') 0.0013382348414793918
# ('Academic writing', 'Text') 2.6764696829587837e-06
# ('Academic writing', 'Coauthorship') 2.6764696829587837e-06
# ('Academic writing', 'Adjectives') 3.3455871036984796e-06
# ('Academic writing', 'Adverbs') 3.3455871036984796e-06
# ('Academic writing', 'Blogging') 2.6764696829587837e-06
# ('Academy of Management Journal', 'Bibliometric analysis') 0.000580159637399956
# ('Academy of Management Journal', 'Network analysis') 8.82094658566617e-05
# ('Academy of Management Journal', 'Gephi (TM)') 1.3382348414793919e-06
# ('Academy of Management Journal', 'Citation analysis') 0.0006752186775886936
# ('Acceptance', 'Ecology') 1.3382348414793919e-06
# ('Acceptance', 'Scientific publication') 0.0013395730763208712
# ('Acceptance', 'Affecting variables') 1.3382348414793919e-06
# ('Acceptance', 'Publishing process') 1.3382348414793919e-06
# ('Action research', 'H-index') 0.0013382348414793918
# ('Action research', 'D-index') 1.3382348414793919e-06
# ('Action research', 'Article download') 1.3382348414793919e-06
# ('Action research', 'Scientific article') 1.3382348414793919e-06
# ('Action research', 'Regional repository') 1.3382348414793919e-06
# ('Adaptive lasso estimators', 'Operations research') 1.3382348414793919e-06
# ('Adaptive lasso estimators', 'Journal lists') 1.3382348414793919e-06
# ('Adaptive lasso estimators', 'Meta-ranking') 1.3382348414793919e-06
# ('Adjectives', 'Readability') 0.001340242193741611
# ('Adjectives', 'Adverbs') 1.3382348414793919e-06
# ('Adverbs', 'Readability') 0.001340242193741611
# ('Adverse incentive effects', 'Research') 0.00134224954600383
# ('Adverse incentive effects', 'Norway') 1.3382348414793919e-06
# ('Adverse incentive effects', 'Reward system') 1.3382348414793919e-06
# ('Affecting variables', 'Ecology') 1.3382348414793919e-06
# ('Affecting variables', 'Scientific publication') 0.0013395730763208712
# ('Affecting variables', 'Publishing process') 1.3382348414793919e-06
# ('Affiliations', 'Landmark papers') 1.3382348414793919e-06
# ('Affiliations', 'Decisive work') 1.3382348414793919e-06
# ('Affiliations', 'Nobel Prize') 1.3382348414793919e-06
# ('Affiliations', 'Researcher mobility') 1.3382348414793919e-06
# ('Age', 'Performance-based funding') 1.3382348414793919e-06
# ('Age', 'Data integration') 5.675728175336745e-05
# ('Age', 'Research information systems') 1.8735287780711485e-05
# ('Age', 'Scandinavia') 1.3382348414793919e-06
# ('Age', 'Productivity') 2.09205403095558e-05
# ('Age', 'Gender') 1.3382348414793919e-06
# ('Age', 'Bibliometrics') 0.001244498201318717
# ('Age of references', 'Emerging topic') 1.3382348414793919e-06
# ('Age of references', 'Massive gathering') 1.3382348414793919e-06
# ('Age of references', 'Multidisciplinary research field') 1.3382348414793919e-06
# ('Age of references', 'Citation analysis') 0.0011947944116834732
# ('Age of references', 'Intellectual base') 0.00014611689947887992
# ('Agent-based model', 'Publishing') 0.00019492847666272318
# ('Agent-based model', 'Peer review') 0.0011473210693411044
# ('Agent-based model', 'Complex systems') 1.3382348414793919e-06
# ('Agent-based model', 'Computer simulation') 1.3382348414793919e-06
# ('Aggregation', 'Field-normalization') 1.3382348414793919e-06
# ('Aggregation', 'All-sciences case') 1.3382348414793919e-06
# ('Aggregation', 'Citation analysis') 0.00134224954600383
# ('Aging', 'Scholarly communication') 0.0013435877808453095
# ('Aging', 'Cohorts') 1.3382348414793919e-06
# ('Agricultural science journals', 'Revealed preference study') 1.3382348414793919e-06
# ('Agricultural science journals', 'Usability') 1.3382348414793919e-06
# ('Agricultural science journals', 'Stated preference study') 1.3382348414793919e-06
# ('Agricultural science journals', 'Indonesia') 1.3382348414793919e-06
# ('Agricultural science journals', 'Journal quality') 0.0013382348414793918
# ('Agricultural science journals', 'Trustworthiness') 1.3382348414793919e-06
# ('Agriculture', 'Power laws') 4.344104905840789e-05
# ('Agriculture', 'Research evaluation') 0.005749378916393572
# ('Agriculture', 'Fields of science') 4.344104905840791e-05
# ('Agriculture', 'Classification') 0.0009706055384408973
# ('Agriculture', 'Co-authorship networks') 0.0025190300403402518
# ('Agriculture', 'Interdisciplinary collaboration') 0.0007266190835544194
# ('Agriculture', 'Research groups') 4.344104905840789e-05
# ('Agriculture', 'Collaborative funding initiatives') 0.0007266190835544197
# ('Agriculture', 'Climate change') 0.00040845619465583097
# ('Agriculture', 'Knowledge hub') 0.0007266190835544194
# ('Agriculture', 'EU research policy') 0.0007266190835544197
# ('Algorithmic historiography', 'Reference Publication Year Spectroscopy') 1.3382348414793919e-06
# ('Algorithmic historiography', 'Bibliometrics') 0.0008572482803098137
# ('Algorithmic historiography', 'Citation analysis') 0.00048500126569401696
# ('Algorithmic historiography', 'Multi-RPYS') 1.3382348414793919e-06
# ('All-sciences case', 'Citation analysis') 0.00134224954600383
# ('All-sciences case', 'Field-normalization') 1.3382348414793919e-06
# ('Allocation', 'Competition') 1.3382348414793919e-06
# ('Allocation', 'Simulation') 0.0009276564264299349
# ('Allocation', 'Funding') 0.00041593135441537533
# ('Allometry', 'Dynamics of science') 1.3382348414793919e-06
# ('Allometry', 'Scientific fields') 0.0013368966066379124
# ('Allometry', 'Basic research') 1.3382348414793919e-06
# ('Allometry', 'Measuring evolution of research fields') 1.3382348414793919e-06
# ('Allometry', 'Applied research') 1.3382348414793919e-06
# ('Allometry', 'International research collaboration') 1.3382348414793919e-06
# ('Allometry', 'Evolution of science') 1.3382348414793919e-06
# ('Alphabetization', 'Interfield comparison') 1.3382348414793919e-06
# ('Alternative indicators', 'Social media metrics') 1.3382348414793919e-06
# ('Alternative indicators', 'Research production') 1.3382348414793919e-06
# ('Alternative indicators', 'Language bias') 1.3382348414793919e-06
# ('Alternative indicators', 'Country comparison') 1.3382348414793919e-06
# ('Alternative indicators', 'Altmetrics') 0.0013395730763208712
# ('Alternative metrics', 'Medical research') 1.7397052939232082e-05
# ('Alternative metrics', 'Clinical trials') 1.3382348414793919e-06
# ('Alternative metrics', 'Citation analysis') 0.0010026873725313197
# ('Alternative metrics', 'Altmetrics') 0.00032350335537475577
# ('Altmetric score', 'Altmetrics') 0.0013435877808453095
# ('Altmetrics', 'H-index') 0.0016914285687305334
# ('Altmetrics', 'Open access') 0.003399808943214035
# ('Altmetrics', 'SCImago') 0.000287195392978279
# ('Altmetrics', 'Mathematics') 0.0017925576299444303
# ('Altmetrics', 'Monographs') 0.0006290990396044508
# ('Altmetrics', 'Correlation') 0.001541826350157666
# ('Altmetrics', 'Twitter Index') 0.00134224954600383
# ('Altmetrics', 'Citation analysis') 0.015267239656207559
# ('Altmetrics', 'Climate change') 0.003901488871828961
# ('Altmetrics', 'Usage count') 0.000527475451591632
# ('Altmetrics', 'Impact factor') 0.007270036070512254
# ('Altmetrics', 'Twitter percentiles') 0.00134224954600383
# ('Altmetrics', 'Article usage') 0.0005274754515916331
# ('Altmetrics', 'Vector valued') 0.0004991686214268685
# ('Altmetrics', 'Twitter counts') 0.00134224954600383
# ('Altmetrics', 'Citations') 0.009006637202856535
# ('Altmetrics', 'Data Citation Index') 0.0003224664629001582
# ('Altmetrics', 'Humanities') 0.0008586115362025162
# ('Altmetrics', 'Web of Science') 0.004582609998589009
# ('Altmetrics', 'Literature review') 0.0011575133384705977
# ('Altmetrics', 'Research dissemination') 0.0013235142582231185
# ('Altmetrics', 'Social media metrics') 0.0013395730763208712
# ('Altmetrics', 'Co-citation analysis') 0.0029310158582947898
# ('Altmetrics', 'Research production') 0.0013395730763208712
# ('Altmetrics', 'PeerJ') 0.001292759284965405
# ('Altmetrics', 'Discretised lognormal') 0.001388742299886183
# ('Altmetrics', 'Usage metrics') 0.000527475451591632
# ('Altmetrics', 'Facebook') 0.0012927592849654047
# ('Altmetrics', 'Public understanding science') 0.001292759284965405
# ('Altmetrics', 'Indicators') 0.003991958259885726
# ('Altmetrics', 'Social media') 0.0011454692248972834
# ('Altmetrics', 'Rejection rates') 0.0002871953929782789
# ('Altmetrics', 'Medical research') 0.0010366137570496058
# ('Altmetrics', 'Subscriptions') 0.000287195392978279
# ('Altmetrics', 'Citation impact') 0.00926459980756183
# ('Altmetrics', 'Language bias') 0.0013395730763208712
# ('Altmetrics', 'Tweets') 0.000357305564678436
# ('Altmetrics', 'Simulation') 0.0022252589963800847
# ('Altmetrics', 'Citedness') 0.0003224664629001582
# ('Altmetrics', 'Clinical trials') 0.0003235033553747558
# ('Altmetrics', 'Country comparison') 0.0013395730763208712
# ('Altmetrics', 'Meta-analysis') 0.004039877821242052
# ('Altmetrics', 'PlumX Analytics') 0.0013235142582231185
# ('Altmetrics', 'Twitter') 0.0077204233690724875
# ('Altmetrics', 'Research data') 0.0003224664629001583
# ('Altmetrics', 'Philosophy') 0.0002871953929782789
# ('Altmetrics', 'Model') 0.0004991686214268696
# ('Altmetrics', 'Policy documents') 0.001297905725043404
# ('Alzheimer', 'MeSH') 1.3382348414793919e-06
# ('Alzheimer', 'Journal') 1.3382348414793919e-06
# ('Alzheimer', 'Citation') 9.367643890355742e-06
# ('Alzheimer', 'Main path') 1.3382348414793919e-06
# ('Analysis', 'Data similarity') 1.3382348414793919e-06
# ('Analysis', 'Bibliometry') 0.0013435877808453095
# ('Application of indicators', 'Science') 1.3382348414793919e-06
# ('Application of indicators', 'Science and technology indicators') 1.3382348414793919e-06
# ('Application of indicators', 'Mapping of science') 0.00134224954600383
# ('Applied linguistics', 'Diachronic study') 1.3382348414793919e-06
# ('Applied linguistics', 'Research titles') 1.3382348414793919e-06
# ('Applied linguistics', 'Categorical framework') 1.3382348414793919e-06
# ('Applied research', 'Dynamics of science') 1.3382348414793919e-06
# ('Applied research', 'Scientific fields') 0.0013368966066379124
# ('Applied research', 'Measuring evolution of research fields') 1.3382348414793919e-06
# ('Applied research', 'Basic research') 1.3382348414793919e-06
# ('Applied research', 'International research collaboration') 1.3382348414793919e-06
# ('Applied research', 'Evolution of science') 1.3382348414793919e-06
# ('Applied science', 'Basic science') 1.3382348414793919e-06
# ('Applied science', 'Bibliometric analysis') 0.0011639416480547938
# ('Applied science', 'Research orientation') 1.3382348414793919e-06
# ('Applied science', 'Web of science') 0.00017830789794903674
# ('Article co-citation network', 'Group dynamics') 1.3382348414793919e-06
# ('Article co-citation network', 'Tag extraction') 1.3382348414793919e-06
# ('Article co-citation network', 'Multidisciplinarity') 1.3382348414793919e-06
# ('Article download', 'H-index') 0.0013382348414793918
# ('Article download', 'D-index') 1.3382348414793919e-06
# ('Article download', 'Scientific article') 1.3382348414793919e-06
# ('Article download', 'Regional repository') 1.3382348414793919e-06
# ('Article life', 'Bibliometric') 0.00045622624890262324
# ('Article life', 'Collaboration') 0.00047521698849917307
# ('Article life', 'SCI-EXPANDED') 0.00041214454344351423
# ('Article life', 'Top-cited articles') 1.3382348414793919e-06
# ('Article usage', 'Web of Science') 0.0008147740944121986
# ('Article usage', 'Usage metrics') 1.3382348414793919e-06
# ('Article usage', 'Usage count') 1.3382348414793919e-06
# ('Article-level metrics', 'Network centrality analysis') 1.3382348414793919e-06
# ('Article-level metrics', 'Paper filtering') 1.3382348414793919e-06
# ('Articles', 'Impact') 0.0010973496492624553
# ('Articles', 'Readability') 0.0020209272689868107
# ('Articles', 'Value') 0.00013046993094026178
# ('Articles', 'Scholarly journals') 0.00013046993094026186
# ('Articles', 'Publication') 0.000130469930940262
# ('Articles', 'Information science') 0.0002887038955695428
# ('Articles', 'Dental') 0.00010007503670961685
# ('Articles', 'Statistical reporting') 0.00010007503670961696
# ('Articles', 'Research papers') 0.0013409113111623506
# ('Articles', 'France') 0.000130469930940262
# ('Articles', 'Research outcomes') 0.00013046993094026186
# ('Articles', 'Titles') 0.0013409113111623506
# ('Articles', 'Clickbait') 0.0013409113111623506
# ('Articles', 'h-Index') 0.0008353627416632325
# ('Articles', 'Bibliometrics') 0.007948544359013255
# ('Articles', 'Bibliometry') 0.00039140979282078575
# ('Articles', 'Questions') 0.0013409113111623506
# ('Articles', 'e-Journals') 0.00013046993094026178
# ('Articles', 'ScienceDirect') 0.00013046993094026186
# ('Articles', 'Downloads') 0.00013046993094026205
# ('Articles', 'Citations') 0.0015729662051925067
# ('Artificial intelligence', 'Transportation engineering') 1.3382348414793919e-06
# ('Artificial intelligence', 'Natural language processing') 1.3382348414793919e-06
# ('Artificial intelligence', 'Scientometrics') 0.00033092071026344865
# ('Artificial intelligence', 'Informetrics') 1.3382348414793919e-06
# ('Artificial intelligence', 'Bibliometrics') 0.0010099906008989026
# ('Asperger syndrome', 'Bibliometric') 0.00134224954600383
# ('Asperger syndrome', 'Executive functions') 1.3382348414793919e-06
# ('Asperger syndrome', 'Autism spectrum disorders') 1.3382348414793919e-06
# ('Assessment of monographs', 'Databases') 1.3382348414793919e-06
# ('Assessment of monographs', 'Data curation') 1.3382348414793919e-06
# ('Assessment of monographs', 'Interoperability') 0.00134224954600383
# ('Association rule', 'Data base') 1.3382348414793919e-06
# ('Association rule', 'Clustering') 3.1126705158124234e-05
# ('Association rule', 'Regression analysis') 1.3382348414793919e-06
# ('Association rule', 'HCV and Egypt') 1.3382348414793919e-06
# ('Association rule', 'PubMed') 1.3382348414793919e-06
# ('Association rule', 'Data mining') 0.00010866804850903942
# ('Association rule', 'Bibliometrics') 0.00119977832265371
# ('Author assessment', 'Paper assessment') 1.3382348414793919e-06
# ('Author assessment', 'Indirect indicators') 1.3382348414793919e-06
# ('Author assessment', 'fas(k)-index') 1.3382348414793919e-06
# ('Author assessment', 'fp(k)-index') 1.3382348414793919e-06
# ('Author assessment', 'fa(k)-index') 1.3382348414793919e-06
# ('Author bibliographic coupling', 'Imetrics') 1.3382348414793919e-06
# ('Author bibliographic coupling', 'Citation impact') 0.0013435877808453095
# ('Author citation networks', 'Knowledge communication') 1.3382348414793919e-06
# ('Author citation networks', 'Library and information science') 0.0013409113111623506
# ('Author citation networks', 'Knowledge flow') 1.3382348414793919e-06
# ('Author citation networks', 'Shortest distance') 1.3382348414793919e-06
# ('Author co-citation analysis', 'Co-citation analysis') 5.918282311953534e-05
# ('Author co-citation analysis', 'Citation analysis') 0.00044590466944074134
# ('Author co-citation analysis', 'Bibliometrics') 0.0008398385231265121
# ('Author co-citation analysis (ACA)', 'Organization theory') 1.3382348414793919e-06
# ('Author co-citation analysis (ACA)', 'Exploitation') 1.3382348414793919e-06
# ('Author co-citation analysis (ACA)', 'Organizational ambidexterity') 1.3382348414793919e-06
# ('Author co-citation analysis (ACA)', 'Citation analysis') 0.0004836630308525374
# ('Author co-citation analysis (ACA)', 'Bibliometrics') 0.000855910045468334
# ('Author co-citation analysis (ACA)', 'Exploration') 1.3382348414793919e-06
# ('Author contribution', 'Gift authorship') 1.3382348414793919e-06
# ('Author contribution', 'Gastroenterology') 1.3382348414793919e-06
# ('Author contribution', 'Author number') 1.3382348414793919e-06
# ('Author identification', 'Mathematical model') 1.3382348414793919e-06
# ('Author identification', 'ResearcherID') 1.3382348414793919e-06
# ('Author identification', 'Author productivity') 1.3382348414793919e-06
# ('Author identification', 'Citation impact') 0.0013409113111623506
# ('Author name disambiguation', 'Scientific collaboration') 0.0013409113111623506
# ('Author name disambiguation', 'Co-authorship network') 1.3382348414793919e-06
# ('Author name disambiguation', 'Record linkage') 1.3382348414793919e-06
# ('Author name disambiguation', 'Bibliographic data source') 1.3382348414793919e-06
# ('Author networks', 'Work engagement') 1.3382348414793919e-06
# ('Author networks', 'Social network analysis') 0.00134224954600383
# ('Author networks', 'Hidden patterns') 1.3382348414793919e-06
# ('Author number', 'Gift authorship') 1.3382348414793919e-06
# ('Author number', 'Gastroenterology') 1.3382348414793919e-06
# ('Author productivity', 'Mathematical model') 1.3382348414793919e-06
# ('Author productivity', 'Citation impact') 0.0013409113111623506
# ('Author productivity', 'ResearcherID') 1.3382348414793919e-06
# ('Author-pay model', 'Citation advantage') 1.3382348414793919e-06
# ('Author-pay model', 'Humanities') 0.00015932940615076427
# ('Author-pay model', 'Gold Open Access') 1.3382348414793919e-06
# ('Author-pay model', 'Social sciences') 0.0004875089408707878
# ('Author-pay model', 'Open Access Publishing') 1.3382348414793919e-06
# ('Author-pay model', 'Citations') 0.0006940729641408011
# ('Authority control', 'Coauthorship networks') 1.3382348414793919e-06
# ('Authority control', 'Network evolution') 1.3382348414793919e-06
# ('Authority control', 'Small-world networks') 1.3382348414793919e-06
# ('Authority control', 'Bibliometrics') 0.0013409113111623506
# ('Authorship', 'Development') 1.3382348414793919e-06
# ('Authorship', 'Ethical publishing: Mathilda effect') 1.3382348414793919e-06
# ('Authorship', 'Scientific publication') 8.029409048876352e-06
# ('Authorship', 'LMIC') 1.3382348414793919e-06
# ('Authorship', 'Matthew effect') 0.0013328819021134744
# ('Authorship citation network', 'Credit diffusion') 1.3382348414793919e-06
# ('Authorship citation network', 'Scientific impact') 1.3382348414793919e-06
# ('Authorship networks', 'Text mining') 1.8832449241679083e-05
# ('Authorship networks', 'Interdisciplinarity') 0.0002985033868768328
# ('Authorship networks', 'Chornobyl disaster') 1.3382348414793919e-06
# ('Authorship networks', 'Terms indentification') 1.3382348414793919e-06
# ('Authorship networks', 'Bibliometric analysis') 0.0010235754750438375
# ('Authorship networks', 'Topic evolution') 1.3382348414793919e-06
# ('Authorship pattern', 'Social sciences citation index') 1.3382348414793919e-06
# ('Authorship pattern', 'Research output') 0.0003989551792304007
# ('Authorship pattern', 'Reference pattern') 1.3382348414793919e-06
# ('Authorship pattern', 'Citation pattern') 1.1413231433759954e-05
# ('Authorship pattern', 'Scholarly output') 1.3382348414793919e-06
# ('Authorship pattern', 'Web of science') 0.000277400923701439
# ('Authorship pattern', 'International business') 0.0004067450384494274
# ('Authorship pattern', 'Scientometric analysis') 1.3382348414793919e-06
# ('Authorship pattern', 'Content analysis') 0.0002437204686643622
# ('Authorship pattern', 'Mapping research') 1.3382348414793919e-06
# ('Autism spectrum disorders', 'Bibliometric') 0.00134224954600383
# ('Autism spectrum disorders', 'Executive functions') 1.3382348414793919e-06
# ('Automated impact analysis', 'Science of science management') 1.3382348414793919e-06
# ('Automated impact analysis', 'Research evaluation') 0.00030286450492308676
# ('Automated impact analysis', 'Bibliometrics') 0.001040723275922223
# ('Average JIF percentile', 'Quantile regression') 1.3382348414793919e-06
# ('Average JIF percentile', 'Impact factor') 0.0013435877808453095
# ('BRICS', 'G-7') 1.3382348414793919e-06
# ('BRICS', 'High-technology') 1.3382348414793919e-06
# ('BRICS', 'Economic cooperation') 1.3382348414793919e-06
# ('BRICS', 'Scientific collaboration') 0.0013409113111623506
# ('BRICS countries', 'Probabilistic affinity index') 1.3382348414793919e-06
# ('BRICS countries', 'Network analysis') 0.00134224954600383
# ('BRICS countries', 'International scientific collaboration') 1.3382348414793919e-06
# ('Bankruptcy', 'Credit risk') 1.3382348414793919e-06
# ('Bankruptcy', 'Multivariate data analysis') 1.3382348414793919e-06
# ('Bankruptcy', 'Bibliometrics') 0.00134224954600383
# ('Barycenter', 'Research evaluation') 0.0013395730763208712
# ('Barycenter', 'Similarity matrix') 1.3382348414793919e-06
# ('Barycenter', 'Matching research expertise') 1.3382348414793919e-06
# ('Barycenter', 'Journal overlay map') 1.3382348414793919e-06
# ('Barycenter', 'Similarity-adapted publication vector') 1.3382348414793919e-06
# ('Basic and applied science', 'Interdisciplinary research') 1.3382348414793919e-06
# ('Basic and applied science', 'Cognitive distance') 1.3382348414793919e-06
# ('Basic and applied science', 'Cost of learning') 1.3382348414793919e-06
# ('Basic and applied science', 'Translational research') 1.3382348414793919e-06
# ('Basic research', 'Dynamics of science') 1.3382348414793919e-06
# ('Basic research', 'Scientific fields') 0.0013368966066379124
# ('Basic research', 'Measuring evolution of research fields') 1.3382348414793919e-06
# ('Basic research', 'International research collaboration') 1.3382348414793919e-06
# ('Basic research', 'Evolution of science') 1.3382348414793919e-06
# ('Basic research competitiveness index', 'Biomass energy field') 1.3382348414793919e-06
# ('Basic research competitiveness index', 'Modelling and empirical study') 1.3382348414793919e-06
# ('Basic research competitiveness index', 'Basic research performance') 1.3382348414793919e-06
# ('Basic research competitiveness index', 'International comparison') 1.3382348414793919e-06
# ('Basic research performance', 'Biomass energy field') 1.3382348414793919e-06
# ('Basic research performance', 'Modelling and empirical study') 1.3382348414793919e-06
# ('Basic research performance', 'International comparison') 1.3382348414793919e-06
# ('Basic science', 'Bibliometric analysis') 0.0011639416480547938
# ('Basic science', 'Research orientation') 1.3382348414793919e-06
# ('Basic science', 'Web of science') 0.00017830789794903674
# ('Basic sciences', 'North-South and South-South collaboration') 1.3382348414793919e-06
# ('Basic sciences', 'Scientific productivity and coauthorships') 1.3382348414793919e-06
# ('Basic sciences', 'Southern Africa') 1.3382348414793919e-06
# ('Bayesian authors', 'Bayesian reviewers') 1.3382348414793919e-06
# ('Bayesian authors', 'Overconfidence') 7.360291628136655e-06
# ('Bayesian authors', 'Online tool') 1.3382348414793919e-06
# ('Bayesian authors', 'Confirmatory bias') 1.3382348414793919e-06
# ('Bayesian authors', 'Peer review') 0.001333551019534214
# ('Bayesian reviewers', 'Overconfidence') 7.360291628136655e-06
# ('Bayesian reviewers', 'Online tool') 1.3382348414793919e-06
# ('Bayesian reviewers', 'Confirmatory bias') 1.3382348414793919e-06
# ('Bayesian reviewers', 'Peer review') 0.001333551019534214
# ('Beauty coefficient', 'Sleeping beauty') 1.3382348414793919e-06
# ('Beauty coefficient', 'Delayed recognition') 1.3382348414793919e-06
# ("Benford's law", 'JCR') 1.3382348414793919e-06
# ("Benford's law", 'Bibliometric indicators') 0.0009674795951498743
# ("Benford's law", 'Journal Citation Reports') 0.0003761081856954341
# ('Best worst method (BWM)', 'University-industry collaboration') 6.691174207396959e-06
# ('Best worst method (BWM)', 'Multi-criteria decision-making') 1.3382348414793919e-06
# ('Best worst method (BWM)', 'Collaborative Ph.D. project') 1.3382348414793919e-06
# ('Best worst method (BWM)', 'Efficiency') 0.001335558371796433
# ('Bibliographic coupling', 'h-Core') 0.0013409113111623506
# ('Bibliographic coupling', 'Fixed window') 6.691174207396959e-06
# ('Bibliographic coupling', 'Hybrid clustering') 0.0013409113111623506
# ('Bibliographic coupling', 'Similarity measures') 0.0013409113111623506
# ('Bibliographic coupling', 'Citation windows') 6.691174207396959e-06
# ('Bibliographic coupling', 'Citing half life') 6.691174207396959e-06
# ('Bibliographic coupling', 'Sliding window') 6.691174207396959e-06
# ('Bibliographic coupling', 'OLED') 6.691174207396959e-06
# ('Bibliographic coupling', 'Research fronts') 0.006664409510567372
# ('Bibliographic coupling', 'Core documents') 0.0013409113111623506
# ('Bibliographic data source', 'Scientific collaboration') 0.0013409113111623506
# ('Bibliographic data source', 'Co-authorship network') 1.3382348414793919e-06
# ('Bibliographic data source', 'Record linkage') 1.3382348414793919e-06
# ('Bibliography analysis', 'Graphene') 6.691174207396959e-06
# ('Bibliography analysis', 'Specialization score') 1.3382348414793919e-06
# ('Bibliography analysis', 'Interdisciplinarity') 0.0013342201369549538
# ('Bibliography analysis', 'Innovation trajectory') 1.3382348414793919e-06
# ('Bibliometric', 'Knowledge management') 3.17340578938726e-05
# ('Bibliometric', 'Research productivity') 0.002169528568671362
# ('Bibliometric', 'National innovation system') 0.00134224954600383
# ('Bibliometric', 'HistCite') 0.00134224954600383
# ('Bibliometric', 'Citation analysis') 0.006292710556909815
# ('Bibliometric', 'Top-cited articles') 0.0004562262489026233
# ('Bibliometric', 'Collaboration') 0.0013802077330879459
# ('Bibliometric', 'SCI-EXPANDED') 0.0009816838995298236
# ('Bibliometric', 'National culture') 8.970612681805543e-05
# ('Bibliometric', 'Innovation studies') 0.00134224954600383
# ('Bibliometric', 'Executive functions') 0.00134224954600383
# ('Bibliometric', 'International business') 0.0004667153279411395
# ('Bibliometric', 'Quantitative analysis') 8.970612681805544e-05
# ('Bibliometric analysis', 'Impact') 0.004844823084245383
# ('Bibliometric analysis', 'Innovation') 0.007296267815042288
# ('Bibliometric analysis', 'Historical literature review') 0.0013409113111623506
# ('Bibliometric analysis', 'Double-counting of articles') 0.0006443979735154218
# ('Bibliometric analysis', 'Terms indentification') 0.0010235754750438366
# ('Bibliometric analysis', 'Research impact assessment') 0.00134224954600383
# ('Bibliometric analysis', 'Supply chain') 0.0013409113111623506
# ('Bibliometric analysis', 'Case study') 0.003187910044180375
# ('Bibliometric analysis', 'Ecodesign') 0.0013395730763208712
# ('Bibliometric analysis', 'Scientometrics') 0.01349535708789905
# ('Bibliometric analysis', 'SCI-EXPANDED') 0.001918536773238614
# ('Bibliometric analysis', 'Micro/nano-bubble') 0.0006762010861905967
# ('Bibliometric analysis', 'Gender studies') 0.0005987251235446978
# ('Bibliometric analysis', 'Scientific mapping') 0.0010808458867353162
# ('Bibliometric analysis', 'Green products') 0.0013395730763208712
# ('Bibliometric analysis', 'Logistics') 0.0013409113111623506
# ('Bibliometric analysis', 'Sustainability') 0.0013395730763208712
# ('Bibliometric analysis', 'Sustainable development') 0.0013395730763208712
# ('Bibliometric analysis', 'Multivariate scaling') 0.0013275289627475567
# ('Bibliometric analysis', 'Intellectual structure') 0.010620231701980454
# ('Bibliometric analysis', 'Strategic knowledge management') 0.0013275289627475567
# ('Bibliometric analysis', 'Research trends') 0.0004357335610271363
# ('Bibliometric analysis', 'Non WoS citation impact analysis') 0.00134224954600383
# ('Bibliometric analysis', 'Business cycle theory') 0.0010453716517223202
# ('Bibliometric analysis', 'Monte Carlo simulations') 0.00042591520427675113
# ('Bibliometric analysis', 'Economics') 0.0007854134814997896
# ('Bibliometric analysis', 'Diversity analysis') 0.0009427507733656684
# ('Bibliometric analysis', 'Text mining') 0.005274463103934477
# ('Bibliometric analysis', 'Ergonomics') 0.0013409113111623506
# ('Bibliometric analysis', 'Fractional cointegration') 0.00104537165172232
# ('Bibliometric analysis', 'Classification framework') 0.0013409113111623506
# ('Bibliometric analysis', 'Network analysis') 0.005767345518191501
# ('Bibliometric analysis', 'Human factors') 0.0013409113111623506
# ('Bibliometric analysis', 'Strategic behavior') 0.0013275289627475567
# ('Bibliometric analysis', 'Gephi (TM)') 0.000580159637399956
# ('Bibliometric analysis', 'Historical research phases') 0.0013395730763208712
# ('Bibliometric analysis', 'Interdisciplinarity') 0.009832770590576457
# ('Bibliometric analysis', 'Web of science') 0.0026883676454913822
# ('Bibliometric analysis', 'Impact factor') 0.014779823630330851
# ('Bibliometric analysis', 'Chornobyl disaster') 0.001023575475043838
# ('Bibliometric analysis', 'Co-citations') 0.0013275289627475567
# ('Bibliometric analysis', 'Bibliometrics') 0.01412201169797795
# ('Bibliometric analysis', 'Intellectual base') 0.0033885832036941233
# ('Bibliometric analysis', 'CRIS system') 0.00134224954600383
# ('Bibliometric analysis', 'Citations') 0.010693159217393253
# ('Bibliometric analysis', 'Collaboration network') 0.005740835451597508
# ('Bibliometric analysis', 'Content analysis') 0.002672616638260759
# ('Bibliometric analysis', 'International collaboration') 0.007342997216981359
# ('Bibliometric analysis', 'Topic evolution') 0.0010235754750438366
# ('Bibliometric analysis', 'Radio frequency identification') 0.0013409113111623506
# ('Bibliometric analysis', 'Strategic entrepreneurship') 0.0013275289627475567
# ('Bibliometric analysis', 'Research orientation') 0.0011639416480547934
# ('Bibliometric analysis', 'RFID') 0.0013409113111623506
# ('Bibliometric analysis', 'Scientific production') 0.003207966890285853
# ('Bibliometric analysis', 'Citation analysis') 0.015103981419610692
# ('Bibliometric analysis', 'Strategic management') 0.0013275289627475567
# ('Bibliometric analysis', 'GMF') 0.0010808458867353158
# ('Bibliometric analysis', 'Social Media') 0.0009427507733656664
# ('Bibliometric analysis research evaluation', 'Rehabilitation') 1.3382348414793919e-06
# ('Bibliometric analysis research evaluation', 'Virtual reality') 1.3382348414793919e-06
# ('Bibliometric database', 'Error correction') 1.3382348414793919e-06
# ('Bibliometric database', 'Engineering-Manufacturing journals') 1.3382348414793919e-06
# ('Bibliometric database', 'Old dirty data') 1.3382348414793919e-06
# ('Bibliometric database', 'Omitted citations') 1.3382348414793919e-06
# ('Bibliometric database', 'Database errors') 1.3382348414793919e-06
# ('Bibliometric evaluation', 'Institutional rankings') 0.0013031730886326318
# ('Bibliometric evaluation', 'Italian VQR') 9.226651290985593e-05
# ('Bibliometric evaluation', 'Funding acknowledgement') 0.00029762529297492685
# ('Bibliometric evaluation', 'Evaluation processes') 0.0013031730886326318
# ('Bibliometric evaluation', 'Excellence Initiative') 0.0016564073872096371
# ('Bibliometric evaluation', "Cohen's kappa") 9.22665129098559e-05
# ('Bibliometric evaluation', 'Peer review') 0.0023225616284283713
# ('Bibliometric evaluation', 'Research system') 0.0002976252929749269
# ('Bibliometric evaluation', 'University policy') 0.004636926829368828
# ('Bibliometric evaluation', 'Germany') 0.00029762529297492685
# ('Bibliometric evaluation', 'Highly cited') 0.004206927845422476
# ('Bibliometric evaluation', 'Research assessment') 0.006451602574546872
# ('Bibliometric evaluation', 'Meta-analysis') 0.00116015937144686
# ('Bibliometric evaluation', 'Informed peer review') 9.226651290985593e-05
# ('Bibliometric indexes', 'Reproductive medicine') 1.3382348414793919e-06
# ('Bibliometric indexes', 'Scientometrics') 0.001275948120122718
# ('Bibliometric indexes', 'Medicine') 1.3382348414793919e-06
# ('Bibliometric indexes', 'Social networks') 6.630142588111302e-05
# ('Bibliometric indicator', 'Performance') 2.8270211026252173e-05
# ('Bibliometric indicator', 'Prediction errors') 1.3382348414793919e-06
# ('Bibliometric indicator', 'Productivity') 0.0009195064700362097
# ('Bibliometric indicator', 'Mathematics') 0.0003917963952584084
# ('Bibliometric indicator', 'Decision making') 1.3382348414793919e-06
# ('Bibliometric indicator', 'ROC') 1.3382348414793919e-06
# ('Bibliometric indicator', 'Receiver operating characteristic') 1.3382348414793919e-06
# ('Bibliometric indicators', 'JCR') 0.0009674795951498745
# ('Bibliometric indicators', 'Scientometrics') 0.013655827993697944
# ('Bibliometric indicators', 'Biopharmaceuticals') 5.59428887600359e-05
# ('Bibliometric indicators', 'Partial least squares') 0.0009769429107993155
# ('Bibliometric indicators', 'R&D and innovation construt') 0.0009769429107993155
# ('Bibliometric indicators', 'Pharmaceutical industry') 5.594288876003587e-05
# ('Bibliometric indicators', 'University ranking') 0.005311655695460207
# ('Bibliometric indicators', 'Indicator development') 0.0013368966066379124
# ('Bibliometric indicators', 'Relative indicators') 0.0013368966066379124
# ('Bibliometric indicators', 'Journal impact factor') 0.0013368966066379124
# ('Bibliometric indicators', 'Multinational companies') 5.594288876003588e-05
# ('Bibliometric indicators', 'International collaboration') 0.0030867399200588757
# ('Bibliometric indicators', 'SNIP') 0.0013368966066379124
# ('Bibliometric indicators', 'Source normalization') 0.0013368966066379124
# ('Bibliometric indicators', 'Excellence') 5.594288876003589e-05
# ('Bibliometric indicators', 'Cuba') 0.0007968759671464174
# ('Bibliometric indicators', 'Statistical validity') 0.0013368966066379124
# ('Bibliometric indicators', 'Leadership') 0.0010135459181072495
# ('Bibliometric indicators', 'Subject field bias') 0.0013368966066379124
# ('Bibliometric indicators', 'Journal Citation Reports') 0.0013858637623387813
# ('Bibliometric indicators', 'University R&D and innovation') 0.0009769429107993155
# ('Bibliometric methods', 'Characteristics') 1.3382348414793919e-06
# ('Bibliometric methods', 'China') 0.00024325824177079332
# ('Bibliometric methods', 'Biotechnology') 1.3382348414793919e-06
# ('Bibliometric methods', 'Research collaboration') 0.001098991304233038
# ('Bibliometric profile', 'Institutional collaboration') 0.00134224954600383
# ('Bibliometric profile', 'Space research') 1.3382348414793919e-06
# ('Bibliometric profile', 'European Space Agency') 1.3382348414793919e-06
# ('Bibliometrics', 'Rao-Stirling index') 0.001198602208969515
# ('Bibliometrics', 'Water security') 0.0013342201369549538
# ('Bibliometrics', 'Innovation') 0.011530692190664346
# ('Bibliometrics', 'Web of Science') 0.004338709176712358
# ('Bibliometrics', 'Scientometrics') 0.0313455151848929
# ('Bibliometrics', 'Institutional collaboration') 0.004178209207697219
# ('Bibliometrics', 'Co-citation analysis') 0.0022977405416794937
# ('Bibliometrics', 'Organization theory') 0.0008559100454683351
# ('Bibliometrics', 'Informetrics') 0.001009990600898903
# ('Bibliometrics', 'Funding acknowledgements') 0.0018783661114179615
# ('Bibliometrics', 'Reference Publication Year Spectroscopy') 0.0008572482803098145
# ('Bibliometrics', 'Research funding') 0.012853433850084328
# ('Bibliometrics', 'Data integration') 0.003943775122069655
# ('Bibliometrics', 'Excellence Initiative') 0.007512145142143414
# ('Bibliometrics', 'Research information systems') 0.0029430660419897444
# ('Bibliometrics', 'Indicators') 0.01589293369327653
# ('Bibliometrics', 'Research evaluation') 0.007628607934986365
# ('Bibliometrics', 'Economics') 0.000916958166487244
# ('Bibliometrics', 'IODP') 0.0013409113111623506
# ('Bibliometrics', 'Social sciences') 0.002879390834603657
# ('Bibliometrics', 'Performance analysis') 0.0008531480774482809
# ('Bibliometrics', 'Scientific collaboration') 0.024582527113419992
# ('Bibliometrics', 'Credit risk') 0.00134224954600383
# ('Bibliometrics', 'Exploitation') 0.0008559100454683347
# ('Bibliometrics', 'Organizational ambidexterity') 0.0008559100454683351
# ('Bibliometrics', 'Cluster of Excellence') 0.001268144791656909
# ('Bibliometrics', 'Citation analysis') 0.01641302732474963
# ('Bibliometrics', 'Interdisciplinarity') 0.021036432588493574
# ('Bibliometrics', 'Research collaboration') 0.008415819893000446
# ('Bibliometrics', 'Co-authorship') 0.00397463070172533
# ('Bibliometrics', 'Multivariate data analysis') 0.00134224954600383
# ('Bibliometrics', 'Differences among countries') 0.0013409113111623506
# ('Bibliometrics', 'Research assessment') 0.02177028166140309
# ('Bibliometrics', 'Impact') 0.006577975294397786
# ('Bibliometrics', 'Coauthorship networks') 0.0013409113111623506
# ('Bibliometrics', 'Science classification') 0.0012812256695854355
# ('Bibliometrics', 'Taverna') 0.0013382348414793918
# ('Bibliometrics', 'Case study') 0.007376135168132489
# ('Bibliometrics', 'Research topics') 0.0012812256695854357
# ('Bibliometrics', 'Persian Gulf Region') 0.001198885991553267
# ('Bibliometrics', 'Russia') 0.0018724662889057684
# ('Bibliometrics', 'Neurosciences') 0.0007815761449570875
# ('Bibliometrics', 'Highly cited papers') 0.0012681447916569088
# ('Bibliometrics', 'Centrality') 0.005271357952120062
# ('Bibliometrics', 'Web of Science (WoS) database') 0.0013342201369549538
# ('Bibliometrics', 'University') 0.015749721247008727
# ('Bibliometrics', 'Water quality') 0.00134224954600383
# ('Bibliometrics', 'Clustering') 0.0016617886404704664
# ('Bibliometrics', 'Research productivity') 0.0068476802088321825
# ('Bibliometrics', 'Machine learning') 0.007806648893164982
# ('Bibliometrics', 'SCI-expanded') 0.0012120934625762313
# ('Bibliometrics', 'Tourism') 0.0011158214363152985
# ('Bibliometrics', 'Scandinavia') 0.0012444982013187164
# ('Bibliometrics', 'Productivity') 0.006360004945328736
# ('Bibliometrics', 'Performance-based funding') 0.0012444982013187164
# ('Bibliometrics', 'Spanning tree') 0.0011986022089695144
# ('Bibliometrics', 'Historical roots') 0.0013409113111623506
# ('Bibliometrics', 'Optimization') 0.001198602208969515
# ('Bibliometrics', 'Crisis') 0.0011158214363152987
# ('Bibliometrics', 'R') 0.0013382348414793918
# ('Bibliometrics', 'Mental health') 0.0007815761449570878
# ('Bibliometrics', 'Gini') 0.0010020790896466457
# ('Bibliometrics', 'h-index') 0.004977137590508541
# ('Bibliometrics', 'Data base') 0.0011997783226537094
# ('Bibliometrics', 'Transportation engineering') 0.001009990600898901
# ('Bibliometrics', 'FSS') 0.001022519564759099
# ('Bibliometrics', 'Network evolution') 0.0013409113111623506
# ('Bibliometrics', 'Science of science management') 0.0010407232759222225
# ('Bibliometrics', 'Research trends') 0.0008792807597758142
# ('Bibliometrics', 'Pareto') 0.0010020790896466453
# ('Bibliometrics', 'Missing data') 0.0011986022089695153
# ('Bibliometrics', 'Nanotechnology') 0.0017666587345524928
# ('Bibliometrics', 'Dental') 0.0012435127441356934
# ('Bibliometrics', 'Statistical reporting') 0.0012435127441356927
# ('Bibliometrics', 'Political relations') 0.0011988859915532672
# ('Bibliometrics', 'Monte Carlo simulations') 0.000917672576568561
# ('Bibliometrics', 'Big data') 0.002006560339034629
# ('Bibliometrics', 'River') 0.00134224954600383
# ('Bibliometrics', 'Citation indexes') 0.0007967084240782705
# ('Bibliometrics', 'Research trend') 0.00134224954600383
# ('Bibliometrics', 'Mass spectrometry') 0.0013382348414793918
# ('Bibliometrics', 'Social network analysis (SNA)') 0.009339540958684675
# ('Bibliometrics', 'Italy') 0.001000326639258994
# ('Bibliometrics', 'Gender') 0.0012444982013187168
# ('Bibliometrics', 'Scopus') 0.0024506234806595303
# ('Bibliometrics', 'Computer') 0.0012120934625762306
# ('Bibliometrics', 'Uncertainty') 0.0011986022089695142
# ('Bibliometrics', 'Citation peak') 0.0013409113111623506
# ('Bibliometrics', 'Natural language processing') 0.0010099906008989026
# ('Bibliometrics', 'Technology mining') 0.001287473595279653
# ('Bibliometrics', 'Regression analysis') 0.001199778322653708
# ('Bibliometrics', 'XML') 0.0013382348414793918
# ('Bibliometrics', 'Reference Publication Year Spectroscopy (RPYS)') 0.0013409113111623506
# ('Bibliometrics', 'HCV and Egypt') 0.0011997783226537092
# ('Bibliometrics', 'Geographical information system (GIS)') 0.0012120934625762306
# ('Bibliometrics', 'VOS viewer') 0.0009665167482533218
# ('Bibliometrics', "Elsevier's Scopus") 0.001198885991553266
# ('Bibliometrics', "Peirce's measure") 0.0008531480774482809
# ('Bibliometrics', 'Cliques') 0.0010445523019243057
# ('Bibliometrics', 'Psychology research') 0.000861869030380901
# ('Bibliometrics', 'Iran') 0.0011988859915532668
# ('Bibliometrics', 'Strategic Management Journal') 0.0010445523019243033
# ('Bibliometrics', 'Medicinal chemistry') 0.0013382348414793918
# ('Bibliometrics', "Thomson Reuters' Incites") 0.0011988859915532675
# ('Bibliometrics', 'Data mining') 0.001421861575437554
# ('Bibliometrics', 'Impact factor') 0.02208654199096382
# ('Bibliometrics', 'Scientific workflows') 0.0013382348414793918
# ('Bibliometrics', 'VOS viewer map') 0.0011988859915532677
# ('Bibliometrics', 'Co-cited analysis') 0.0013409113111623506
# ('Bibliometrics', 'International Co-authorship') 0.0011988859915532666
# ('Bibliometrics', 'Overlay analysis') 0.0013409113111623506
# ('Bibliometrics', 'Semantic technologies') 0.0012874735952796532
# ('Bibliometrics', 'Foresight') 0.0012874735952796538
# ('Bibliometrics', 'Small-world networks') 0.0013409113111623506
# ('Bibliometrics', 'Social network analysis') 0.013123187063661126
# ('Bibliometrics', 'Country analysis') 0.0009665167482533239
# ('Bibliometrics', 'Citations') 0.0130931670961001
# ('Bibliometrics', 'Scientific collaboration networks') 0.0008239655301293062
# ('Bibliometrics', 'Consolidation') 0.0011158214363152987
# ('Bibliometrics', 'Tribology') 0.0013409113111623506
# ('Bibliometrics', 'Information networks') 0.000823965530129306
# ('Bibliometrics', 'PubMed') 0.001199778322653708
# ('Bibliometrics', 'Universities') 0.0021840272001344453
# ('Bibliometrics', 'Trend monitoring') 0.001287473595279653
# ('Bibliometrics', 'Multi-RPYS') 0.0008572482803098145
# ('Bibliometrics', 'Exploration') 0.0008559100454683347
# ('Bibliometrics analysis', 'Information Systems & MIS') 1.3382348414793919e-06
# ('Bibliometrics analysis', 'Citations') 0.0013435877808453095
# ('Bibliometry', 'Impact') 0.0014431561761399931
# ('Bibliometry', 'Value') 4.014704524438176e-06
# ('Bibliometry', 'Publication') 4.014704524438176e-06
# ('Bibliometry', 'Scholarly journals') 4.014704524438176e-06
# ('Bibliometry', 'e-Journals') 4.014704524438176e-06
# ('Bibliometry', 'France') 4.014704524438176e-06
# ('Bibliometry', 'Research outcomes') 4.014704524438176e-06
# ('Bibliometry', 'ScienceDirect') 4.014704524438176e-06
# ('Bibliometry', 'Downloads') 4.014704524438176e-06
# ('Bibliometry', 'h-Index') 0.00016148435865933212
# ...
# ('Research output', 'Scientometric analysis') 0.0003989551792304011
# ('Research output', 'System') 0.00026839408126012307
# ('Research output', 'Web of science') 0.0010839728070954663
# ('Research output', 'Statistical analysis') 0.0008473923453564537
# ('Research output', "Researchers' time use") 0.0013395730763208712
# ('Research papers', 'Titles') 1.3382348414793919e-06
# ('Research performance', 'Scientific output') 0.003501773150944609
# ('Research performance', 'Scopus') 0.0011444911251312874
# ('Research performance', 'University rankings') 0.0014803614868117744
# ('Research performance', 'Scientific evaluation') 0.00030944461087264134
# ('Research policy', 'Scientograms') 0.0013395730763208712
# ('Research production', 'Social media metrics') 1.3382348414793919e-06
# ('Research productivity', 'Scientometrics') 0.004929534492796158
# ('Research productivity', 'Scientific publishing') 0.0010291201041152786
# ('Research productivity', 'Semi-nonparametric modeling') 0.0006123761784849401
# ('Research productivity', 'Scientific productivity') 0.004370718344412396
# ('Research productivity', 'h-index') 0.0010759142456789274
# ('Research ranking', 'Scientometrics') 0.0013375657240586522
# ('Research ranking', 'University Ranking') 1.3382348414793919e-06
# ('Research topics', 'Science classification') 1.3382348414793919e-06
# ('Research trend', 'Water quality') 1.3382348414793919e-06
# ('Research trend', 'River') 1.3382348414793919e-06
# ('Research trends', 'Scientometrics') 0.0004038284396141779
# ('Research trends', 'SCI-EXPANDED') 0.00014252637113312464
# ('Research trends', 'SCI-expanded') 0.00013015608342759925
# ('Researcher profiling', 'Social voting systems') 1.3382348414793919e-06
# ('Researcher profiling', 'Vocabularies construction') 1.3382348414793919e-06
# ("Researchers' research agenda setting", 'Survey instrument') 1.3382348414793919e-06
# ('Resource acquisition', 'University governance') 1.3382348414793919e-06
# ('Retraction', 'Scientific misconduct') 1.3382348414793919e-06
# ('Retraction', 'Self-plagiarism') 1.3382348414793919e-06
# ('Revealed comparative advantage', 'Scientific output') 0.0013409113111623506
# ('Revealed preference study', 'Stated preference study') 1.3382348414793919e-06
# ('Revealed preference study', 'Usability') 1.3382348414793919e-06
# ('Revealed preference study', 'Trustworthiness') 1.3382348414793919e-06
# ('Rhetorical structure', 'n-grams') 1.3382348414793919e-06
# ('Risk of bias', 'Study design') 1.3382348414793919e-06
# ('River', 'Water quality') 1.3382348414793919e-06
# ('Robustness', 'Similarity') 1.3382348414793919e-06
# ('Russia', 'Science policies') 0.000267161105286959
# ('Russia', 'Russian Science Citation Index') 0.0002671611052869589
# ('Russia', 'Technology mining') 5.3437715882697696e-05
# ('Russia', 'Semantic technologies') 5.343771588269768e-05
# ('Russia', 'Trend monitoring') 5.3437715882697696e-05
# ('Russian Science Citation Index', 'Science policies') 1.3382348414793919e-06
# ('SCI-EXPANDED', 'Scientometrics') 0.0007422258064001393
# ('SCI-EXPANDED', 'Top-cited articles') 0.0004121445434435143
# ('SCI-EXPANDED', 'SSCI') 0.0002052475934087489
# ('SCI-EXPANDED', 'Web of science') 0.00020266919277787086
# ('SCImago', 'Subscriptions') 1.3382348414793919e-06
# ('SICRIS', 'Scientific collaborations') 0.00024071996178891828
# ('SMEs', 'Technology transfer') 4.014704524438176e-06
# ('SMEs', 'Sectoral innovation systems') 1.3382348414793919e-06
# ('SNIP', 'Source normalization') 1.3382348414793919e-06
# ('SNIP', 'Statistical validity') 1.3382348414793919e-06
# ('SNIP', 'Subject field bias') 1.3382348414793919e-06
# ('SSCI', 'Scientometrics') 0.0011383401874365618
# ('STEM', 'Science policy') 1.3382348414793919e-06
# ('Salton cosine', 'String matching') 1.3382348414793919e-06
# ('Saudi Arabia', 'World Class University') 1.3382348414793919e-06
# ('Save', 'Visibility') 1.3382348414793919e-06
# ('Scale independent', 'Science system') 1.3382348414793919e-06
# ('Scale independent', 'Self-similar') 1.3382348414793919e-06
# ('Scholar activity', 'Scientifics') 1.3382348414793919e-06
# ('Scholarly communication', 'Subdisciplinary differences') 4.014704524438176e-06
# ('Scholarly communication', 'Twitter') 0.004018719228962614
# ('Scholarly journals', 'Value') 1.3382348414793919e-06
# ('Scholarly journals', 'e-Journals') 1.3382348414793919e-06
# ('Scholarly journals', 'ScienceDirect') 1.3382348414793919e-06
# ('Scholarly journals', 'h-Index') 5.3828119553110664e-05
# ('Scholarly output', 'Social sciences citation index') 1.3382348414793919e-06
# ('Scholarly output', 'Web of science') 0.00027740092370144
# ('Scholarly output', 'Scientometric analysis') 1.3382348414793919e-06
# ('Science', 'Science and technology indicators') 1.3382348414793919e-06
# ('Science and technology policy', 'Scientific collaboration') 0.0013395730763208712
# ('Science indicators', 'University policy') 0.0008917948944856134
# ('Science linkages', 'Technology transfer') 0.0013435877808453095
# ('Science navigation map', 'Visualization') 1.3382348414793919e-06
# ('Science system', 'Self-similar') 1.3382348414793919e-06
# ('ScienceDirect', 'e-Journals') 1.3382348414793919e-06
# ('ScienceDirect', 'Value') 1.3382348414793919e-06
# ('ScienceDirect', 'h-Index') 5.3828119553110664e-05
# ('Scientific capital', 'Scientometrics') 0.00134224954600383
# ('Scientific capital', 'Sociology of science') 1.3382348414793919e-06
# ('Scientific collaboration', 'Team science') 0.0013409113111623506
# ('Scientific collaboration', 'Social networks') 0.0009516696776857548
# ('Scientific collaboration', "Thomson Reuters' Incites") 0.00013801061508464493
# ('Scientific collaboration', 'VOS viewer map') 0.00013801061508464493
# ('Scientific collaboration', 'Team formation') 0.000575017029653505
# ('Scientific collaborations', 'Scientometrics') 0.003066980024680529
# ('Scientific collaborations', 'Scientific communities') 0.0005447012399482139
# ('Scientific collaborations', 'Social network analysis') 0.0015484336490796163
# ('Scientific collaborations', 'Scientific networks') 0.00016517771324376325
# ('Scientific evaluation', 'Scientific output') 2.2080874884409966e-05
# ('Scientific fields', 'Scientific productivity') 0.004279812803192101
# ('Scientific fields', 'Southeast Europe countries') 1.0705878731835135e-05
# ('Scientific fields', 'h-Index') 0.006383242413715706
# ('Scientific fields', 'Scientific performance quality') 1.0705878731835135e-05
# ('Scientific misconduct', 'Self-plagiarism') 1.3382348414793919e-06
# ('Scientific networks', 'Scientometrics') 0.0005798967393902444
# ('Scientific networks', 'Social network analysis') 0.000580670196991577
# ('Scientific papers', 'Scientometrics') 0.00134224954600383
# ('Scientific performance quality', 'Scientific productivity') 0.000534976600399012
# ('Scientific performance quality', 'Southeast Europe countries') 1.3382348414793919e-06
# ('Scientific performance quality', 'h-Index') 0.0007979053017144645
# ('Scientific production', 'Western Europe') 0.0013435877808453095
# ('Scientific productivity', 'Southeast Europe countries') 0.000534976600399012
# ('Scientific productivity', 'h-Index') 0.0007220707527798105
# ('Scientific productivity and coauthorships', 'Southern Africa') 1.3382348414793919e-06
# ('Scientific research', 'Technological innovation') 0.0013449260156867889
# ('Scientific software', 'Software citation') 1.3382348414793919e-06
# ('Scientific workflows', 'Taverna') 1.3382348414793919e-06
# ('Scientific workflows', 'XML') 1.3382348414793919e-06
# ('Scientometric analysis', 'Social sciences citation index') 1.3382348414793919e-06
# ('Scientometric analysis', 'Web of science') 0.0002774009237014401
# ('Scientometric indicators', 'Validity') 1.3382348414793919e-06
# ('Scientometric mapping', 'Transport geography') 1.3382348414793919e-06
# ('Scientometrics', 'Software engineering') 0.0013395730763208712
# ('Scientometrics', 'UniversitySelectPlus') 0.0013382348414793918
# ('Scientometrics', 'h-index') 0.003317775082181871
# ('Scientometrics', 'Transportation engineering') 0.00033092071026344974
# ('Scientometrics', 'Sociology of science') 0.00134224954600383
# ('Scientometrics', 'Social networks') 0.001884193243586733
# ('Scientometrics', 'University Ranking') 0.0013375657240586522
# ('Scientometrics', 'Social network analysis') 0.009104253333425513
# ('Scientometrics', 'System') 0.001072517229902228
# ('Scientometrics', 'Stardom in economics') 0.0013409113111623506
# ('Scientometrics', 'Web of science') 0.0017258709128192466
# ('Scientometrics', 'Visual analytics') 0.0013395730763208712
# ('Scopus', 'Web of Science') 6.0372859110368366e-05
# ('Scopus', 'Social sciences') 9.218718848950973e-05
# ('Scopus', 'hIa') 0.0001963904230271846
# ('Scopus', 'Societal relevance') 0.00024578584129675036
# ('Search engine index', 'Webometrics') 0.0013395730763208712
# ('Sectoral innovation systems', 'Technology transfer') 4.014704524438176e-06
# ('Self-citation', 'Self-citation rate') 1.3382348414793919e-06
# ('Semantic technologies', 'Technology mining') 1.3382348414793919e-06
# ('Semantic technologies', 'Trend monitoring') 1.3382348414793919e-06
# ('Sentiment analysis', 'Topological sorting') 1.3382348414793919e-06
# ('Sentiment analysis', 'System of linear inequalities') 1.3382348414793919e-06
# ('Shared leadership', 'Transformational leadership') 1.3382348414793919e-06
# ('Similarity matrix', 'Similarity-adapted publication vector') 1.3382348414793919e-06
# ('Similarity measures', 'h-Core') 1.3382348414793919e-06
# ('Sleeping beauties', 'Vector') 1.3382348414793919e-06
# ('Social epistemology of science', 'Team size') 1.3382348414793919e-06
# ('Social epistemology of science', 'Team diversity') 1.3382348414793919e-06
# ('Social media', 'Twitter') 0.0002186548280040042
# ('Social network analysis', 'Web') 0.0012555637910102865
# ('Social network analysis', 'Work engagement') 0.00134224954600383
# ('Social network analysis', 'Technology transaction') 0.0009323089273966173
# ('Social network analysis', 'Theories') 0.0012555637910102867
# ('Social network analysis', 'Structural dynamics') 0.0012555637910102867
# ('Social network analysis', 'Webometrics') 0.02255275946875393
# ('Social network analysis', 'Social science') 0.0012555637910102867
# ('Social network analysis', 'Strategic Management Journal') 0.00029368253955508884
# ('Social network analysis (SNA)', 'Water security') 9.367643890355742e-06
# ('Social network analysis (SNA)', 'Web of Science (WoS) database') 9.367643890355742e-06
# ('Social scholarship', 'University ranking') 0.00018369340661156567
# ('Social science', 'Web') 1.3382348414793919e-06
# ('Social science', 'Theories') 1.3382348414793919e-06
# ('Social science', 'Structural dynamics') 1.3382348414793919e-06
# ('Social science', 'Webometrics') 8.400928531058487e-05
# ('Social sciences', 'Web of Science') 0.00021245936997906338
# ('Social sciences', 'Societal relevance') 0.0002999451118024552
# ('Social sciences citation index', 'Web of science') 0.00027740092370144017
# ('Social voting systems', 'Vocabularies construction') 1.3382348414793919e-06
# ('Societal relevance', 'Web of Science') 0.00029245892213630476
# ('Source normalization', 'Statistical validity') 1.3382348414793919e-06
# ('Source normalization', 'Subject field bias') 1.3382348414793919e-06
# ('Source-Normalized Impact per Paper (SNIP)', 'Web scraping') 1.3382348414793919e-06
# ('Source-Normalized Impact per Paper (SNIP)', 'Supervised learning') 1.3382348414793919e-06
# ('South Africa', 'Universities') 0.000687093580732014
# ('Southeast Europe countries', 'h-Index') 0.0007979053017144642
# ('Spanish scientific publications', 'Statistical analyses') 1.3382348414793919e-06
# ('Spanish scientific publications', 'WoS') 1.3382348414793919e-06
# ('Spanning tree', 'Uncertainty') 1.3382348414793919e-06
# ('Standard error', 'Stopped sum models') 1.3382348414793919e-06
# ('Stated preference study', 'Usability') 1.3382348414793919e-06
# ('Stated preference study', 'Trustworthiness') 1.3382348414793919e-06
# ('Statistical analyses', 'WoS') 1.3382348414793919e-06
# ('Statistical validity', 'Subject field bias') 1.3382348414793919e-06
# ('Strategic behavior', 'Strategic entrepreneurship') 1.3382348414793919e-06
# ('Strategic behavior', 'Strategic knowledge management') 1.3382348414793919e-06
# ('Strategic behavior', 'Strategic management') 1.3382348414793919e-06
# ('Strategic entrepreneurship', 'Strategic knowledge management') 1.3382348414793919e-06
# ('Strategic entrepreneurship', 'Strategic management') 1.3382348414793919e-06
# ('Strategic knowledge management', 'Strategic management') 1.3382348414793919e-06
# ('Structural dynamics', 'Theories') 1.3382348414793919e-06
# ('Structural dynamics', 'Web') 1.3382348414793919e-06
# ('Structural dynamics', 'Webometrics') 8.400928531058487e-05
# ('Subdisciplinary differences', 'Twitter') 0.0013395730763208712
# ('Subject-classification', 'Text mining') 0.0006572307037984225
# ('Subject-method topic network analysis', 'Text mining') 0.0013422495460038298
# ('Supervised learning', 'Web scraping') 1.3382348414793919e-06
# ('Susceptibility', 'Symbolic magnitude') 1.3382348414793919e-06
# ('Sustainability', 'Sustainable development') 1.3382348414793919e-06
# ('System of linear inequalities', 'Topological sorting') 1.3382348414793919e-06
# ('THE', 'World-class university') 1.3382348414793919e-06
# ('THE', 'USNWR') 1.3382348414793919e-06
# ('THE', 'URAP') 1.3382348414793919e-06
# ('TI value', 'Topic mining') 1.3382348414793919e-06
# ('Taverna', 'XML') 1.3382348414793919e-06
# ('Teaching', 'University engagement') 1.3382348414793919e-06
# ('Teaching', 'University-industry collaboration') 0.0013409113111623504
# ('Teaching', 'University commercialization') 1.3382348414793919e-06
# ('Teaching/research relationship', 'beta-Convergence') 1.3382348414793919e-06
# ('Teaching/research relationship', 'University') 0.0010412627011355958
# ('Team diversity', 'Team size') 1.3382348414793919e-06
# ('Technological evolution', 'USPC reclassification') 1.3382348414793919e-06
# ('Technological positioning', 'Technology structure') 1.3382348414793919e-06
# ('Technology mining', 'Trend monitoring') 1.3382348414793919e-06
# ('Terms indentification', 'Text mining') 1.8832449241679096e-05
# ('Terms indentification', 'Topic evolution') 1.3382348414793919e-06
# ('Text mining', 'Topic evolution') 1.8832449241679096e-05
# ('Theories', 'Web') 1.3382348414793919e-06
# ('Theories', 'Webometrics') 8.400928531058488e-05
# ("Thomson Reuters' Incites", 'VOS viewer map') 1.3382348414793919e-06
# ('Trustworthiness', 'Usability') 1.3382348414793919e-06
# ('Twenty-first century', 'h-Core scores') 1.3382348414793919e-06
# ('Twenty-first century', 'h-Index') 0.00028558190687736485
# ('Twitter Index', 'Twitter percentiles') 1.3382348414793919e-06
# ('Twitter Index', 'Twitter counts') 1.3382348414793919e-06
# ('Twitter counts', 'Twitter percentiles') 1.3382348414793919e-06
# ('URAP', 'World-class university') 1.3382348414793919e-06
# ('URAP', 'USNWR') 1.3382348414793919e-06
# ('USNWR', 'World-class university') 1.3382348414793919e-06
# ('University', 'beta-Convergence') 0.0010412627011355954
# ('University R&D and innovation', 'University ranking') 0.00036530663520451445
# ('University commercialization', 'University engagement') 1.3382348414793919e-06
# ('University commercialization', 'University-industry collaboration') 0.0013409113111623504
# ('University engagement', 'University-industry collaboration') 0.0013409113111623504
# ('Usage count', 'Web of Science') 0.0008147740944121979
# ('Usage count', 'Usage metrics') 1.3382348414793919e-06
# ('Usage metrics', 'Web of Science') 0.0008147740944121979
# ('VOS viewer', 'Web of Science') 0.00023929285206924776
# ('Value', 'h-Index') 5.382811955311069e-05
# ('Value', 'e-Journals') 1.3382348414793919e-06
# ('Water security', 'Web of Science (WoS) database') 1.3382348414793919e-06
# ('Web', 'Webometrics') 8.400928531058487e-05
# ('Web of Science', 'hIa') 0.0002279879316505466
# ('World university ranking', 'Young universities') 1.3382348414793919e-06
# ('e-Journals', 'h-Index') 5.38281195531107e-05
# ('fa(k)-index', 'fp(k)-index') 1.3382348414793919e-06
# ('fa(k)-index', 'fas(k)-index') 1.3382348414793919e-06
# ('fas(k)-index', 'fp(k)-index') 1.3382348414793919e-06
# ('g-index', 'h-index') 0.0003614427216272909
# ('h-Core scores', 'h-Index') 0.00028558190687736485

# %%
f = open(path+'\\output prediction\\{}\\{}\\edge_betweenness.txt'.format(journal, entity), 'w', encoding='utf-8')
for kw, score in edge_betweenness_result.items():
    f.write("{}\t{}\t{}\n".format(kw[0], kw[1], score))
f.close()

# %% [markdown]
# ## extract testing network nodes only appear in training network

# %%
import networkx as nx

# %%
def remove_nodes_not_in_training(test):
    x = test.copy()
    print("nodes: {}\nedges: {}".format(x.number_of_nodes(), x.number_of_edges()))
    intersect_nodes = set(list(test.nodes)).intersection(set(list(training.nodes)))
    testing_nodes_not_in_training = set(list(test.nodes))-intersect_nodes

    x.remove_nodes_from(testing_nodes_not_in_training)
    print("nodes: {}\nedges: {}".format(x.number_of_nodes(), x.number_of_edges()))
    
    return x

test = remove_nodes_not_in_training(test)
# Out:
# nodes: 1223
# edges: 3772
# nodes: 461
# edges: 1164

# %% [markdown]
# #### jaccard

# %%
# We exclude edges already present, to predict only new links
jaccard = linkpred.predictors.Jaccard(G) # , excluded=G.edges()
jaccard_results = jaccard.predict()
# jaccard_top = jaccard_results.top(1000) # katz_results.items length: 7855073

jaccard_test_set = set(linkpred.evaluation.Pair(u, v) for u, v in test.edges())
jaccard_evaluation = linkpred.evaluation.EvaluationSheet(jaccard_results, jaccard_test_set)

jaccard_results.to_file(path+'\\output prediction\\{}\\{}\\result\\jaccard_t1.txt'.format(journal, entity), delimiter='\t', encoding='utf-8')

jaccard_evaluation.to_file(path+'\\output prediction\\{}\\{}\\evaluation\\jaccard_t1.txt'.format(journal, entity))

# %% [markdown]
# #### AdamicAdar

# %%
AdamicAdar = linkpred.predictors.AdamicAdar(G)
AdamicAdar_results = AdamicAdar.predict()

# AdamicAdar_top = AdamicAdar_results.top(1000) # katz_results.items length: 7855073

AdamicAdar_test_set = set(linkpred.evaluation.Pair(u, v) for u, v in test.edges())
AdamicAdar_evaluation = linkpred.evaluation.EvaluationSheet(AdamicAdar_results, AdamicAdar_test_set)

AdamicAdar_results.to_file(path+'\\output prediction\\{}\\{}\\result\\AdamicAdar_t1.txt'.format(journal, entity), delimiter='\t', encoding='utf-8')

AdamicAdar_evaluation.to_file(path+'\\output prediction\\{}\\{}\\evaluation\\AdamicAdar_t1.txt'.format(journal, entity))

# %% [markdown]
# #### Katz_beta001

# %%
katz = linkpred.predictors.Katz(G)
katz_beta001_results = katz.predict(beta=0.001, max_power=5)

# katz_beta001_top = katz_beta001_results.top(1000) # katz_results.items length: 7855073

katz_beta001_test_set = set(linkpred.evaluation.Pair(u, v) for u, v in test.edges())
katz_beta001_evaluation = linkpred.evaluation.EvaluationSheet(katz_beta001_results, katz_beta001_test_set)

katz_beta001_results.to_file(path+'\\output prediction\\{}\\{}\\result\\katz_beta001_t1.txt'.format(journal, entity), delimiter='\t', encoding='utf-8')

katz_beta001_evaluation.to_file(path+'\\output prediction\\{}\\{}\\evaluation\\katz_beta001_t1.txt'.format(journal, entity))
# Out:
# Computing matrix powers: [############################################################] 5/5

# %% [markdown]
# #### Katz_beta01

# %%
katz = linkpred.predictors.Katz(G)
katz_beta01_results = katz.predict(beta=0.01, max_power=5)

# katz_beta01_top = katz_beta01_results.top(1000) # katz_results.items length: 7855073

katz_beta01_test_set = set(linkpred.evaluation.Pair(u, v) for u, v in test.edges())
katz_beta01_evaluation = linkpred.evaluation.EvaluationSheet(katz_beta01_results, katz_beta01_test_set)

katz_beta01_results.to_file(path+'\\output prediction\\{}\\{}\\result\\katz_beta01_t1.txt'.format(journal, entity), delimiter='\t', encoding='utf-8')

katz_beta01_evaluation.to_file(path+'\\output prediction\\{}\\{}\\evaluation\\katz_beta01_t1.txt'.format(journal, entity))
# Out:
# Computing matrix powers: [############################################################] 5/5

# %% [markdown]
# ## Full example
# https://github.com/rafguns/linkpred/issues/12

# %% [markdown]
# #### tn value is -1, something's wrong
#     Solved, with the correct number of tp, fp, fn, can calculate the number of tn
#     tp + fn = num_of_link in testing network
#     tp + fp = num_of_predict_link
#     tn = all_possible_link - tp - fp - fn

# %%
evaluation1 = linkpred.evaluation.StaticEvaluation(jaccard_results, test_set)
