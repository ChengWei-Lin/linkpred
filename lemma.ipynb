# %% [markdown]
# # Task
# 將 node label 進行lemmatization, and stemming
# 然而有可能出現無法對應id 的問題
# 解方如下：
# 1. node: 先把 label lemma 後, id 不改以便對應edge table
# 2. edge: edge_id 對應 node_id, 但將 edge_id 置換成 label
# 3. 如此即便 id不同也會對應至相同label, 因已把 node label lemma了

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Read Files

# %%
import os
import pandas as pd

path = os.getcwd()
scientometric_coauthor_path = path+'\\data\\scientometrics\\co-author\\'
scientometric_cooccur_path = path+'\\data\\scientometrics\\co-occurrence\\'
jasist_coauthor_path = path+'\\data\\jasist\\co-author\\'
jasist_cooccur_path = path+'\\data\\jasist\\co-occurrence\\'

def list_files_paths(files_path):
    files = os.listdir(files_path)
    network_file_paths = []
    mapfile_paths = []
    for file in files:
        print(files_path+file+'\\network.txt')
        print(files_path+file+'\\map.txt')
        network_file_paths.append(files_path+file+'\\network.txt')
        mapfile_paths.append(files_path+file+'\\map.txt')
    return files, network_file_paths, mapfile_paths

files, network_file_paths, mapfile_paths = list_files_paths(jasist_cooccur_path)
# Out:
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2015\network.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2015\map.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2016\network.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2016\map.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2017\network.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2017\map.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2018\network.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2018\map.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2019\network.txt
# C:\Users\Liser\Desktop\linchengwei_link_prediction\data\JASIST\co-occurrence\jasist_2010-2019\map.txt

# %%
def file_transform(file):
    source_list, target_list, weight_list = [], [], []
    with open(file, 'r', encoding='utf-8') as f:
        f = f.read()
        for i, line in enumerate(f.split('\n')):
            for j, ele in enumerate(line.split('\t')):
                if i == 0:
                    ele = ele.replace('\ufeff', '')
                if j == 0:
                    source_list.append(ele)
                elif j== 1:
                    target_list.append(ele)
                elif j == 2:
                    weight_list.append(ele)
    source_list = source_list[:-1]
    return source_list, target_list, weight_list

def to_df(source_list, target_list, weight_list):
    
    df = pd.DataFrame(columns = ['source', 'target', 'weight'])
    df['source'] = source_list
    df['target'] = target_list
    df['weight'] = weight_list

    return df

# %%
df_nodes = []
for f in mapfile_paths:
    df_node = pd.read_csv(f, '\t')
    df_nodes.append(df_node)
# df_node = df_nodes[0]

# %%
df_edges = []
for f in network_file_paths:
    source_list, target_list, weight_list = file_transform(f)
    df_iter = to_df(source_list, target_list, weight_list)
    df_edges.append(df_iter)
# df_edge = df_edges[0]

# %% [markdown]
# # Label Lemmatization

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import nltk
from nltk.stem.porter import *
stemmer = PorterStemmer()
tokens = ['compute', 'computer', 'computed', 'computing']
for token in tokens:
    print(token + ' --> ' + stemmer.stem(token))
# Out:
# compute --> comput
# computer --> comput
# computed --> comput
# computing --> comput

# %%
def label_lemma(df_node):
    df_new_label = pd.DataFrame(columns=['id', 'label','LEMMA', 'STEM'])
    df_new_label['id'] = df_node['id']
    df_new_label['label'] = df_node['label']

    for i in range(len(df_new_label)):
        text = df_new_label.iloc[i]['label']
        doc = nlp(text)
        token_stem = ''
        token_lemma = ''
        for token in doc:
            if token.is_alpha:
                token_stem += stemmer.stem(token.lemma_)
                token_stem += ' '
                token_lemma += token.lemma_
                token_lemma += ' '
    #     print(i, token_lemma, '---------------->', token_stem)
        df_new_label.at[i, 'LEMMA'] = token_lemma
        df_new_label.at[i, 'STEM'] = token_stem
    return df_new_label

# %% [markdown]
# ### 詞彙控制
# 0. label --> 4338
# 1. LEMMA --> 4094
# 2. STEMM --> 4003

# %%
start_i = 500
end_i = start_i+60
df_new_label[start_i:end_i]
# Out:
#       id                              label  \
# 500  501             china-related research
# 501  502  china-us scientific collaboration
# 502  503             chinese academic books
# 503  504                       chinese herb
# 504  505                  chinese immigrant
# 505  506       chinese interpreting studies
# 506  507                    chinese lineage
# 507  508                   chinese medicine
# 508  509                     chinese patent
# 509  510               chinese universities
# 510  511                   chinese-american
# 511  512          cholinesterase inhibitors
# 512  513                                cii
# 513  514                        cipch-index
# 514  515    circular citation area radius r
# 515  516                                cis
# 516  517                           citation
# 517  518            citation acceleration a
# 518  519                  citation accuracy
# 519  520                    citation ageing
# 520  521                     citation aging
# 521  522                  citation analyses
# 522  523                  citation analysis
# 523  524               citation base impact
# 524  525                  citation behavior
# 525  526                    citation biases
# 526  527            citation categorisation
# 527  528                   citation classic
# 528  529                  citation classics
# 529  530                   citation context
# 530  531    citation context classification
# 531  532                  citation contexts
# 532  533                citation contextual
# 533  534                     citation count
# 534  535                    citation counts
# 535  536                  citation database
# 536  537                 citation databases
# 537  538                   citation density
# 538  539              citation distribution
# 539  540        citation distribution model
# 540  541             citation distributions
# 541  542                    citation errors
# 542  543      citation family relationships
# 543  544                 citation frequency
# 544  545               citation generations
# 545  546         citation genetic genealogy
# 546  547                     citation graph
# 547  548                   citation history
# 548  549                    citation impact
# 549  550         citation impact prediction
# 550  551                 citation increment
# 551  552                     citation index
# 552  553            citation index analysis
# 553  554         citation index publication
# 554  555              citation index system
# 555  556                   citation indexes
# 556  557                  citation indexing
# 557  558                citation indicators
# 558  559                   citation indices
# 559  560                   citation linking
#
#                                   LEMMA                          STEM
# 500              china relate research          china relat research
# 501  china us scientific collaboration    china us scientif collabor
# 502              chinese academic book            chines academ book
# 503                       chinese herb                   chines herb
# 504                  chinese immigrant                 chines immigr
# 505         chinese interpreting study        chines interpret studi
# 506                    chinese lineage                 chines lineag
# 507                   chinese medicine                chines medicin
# 508                     chinese patent                 chines patent
# 509                 chinese university                chines univers
# 510                   chinese american               chines american
# 511           cholinesterase inhibitor       cholinesteras inhibitor
# 512                                cii                           cii
# 513                        cipch index                   cipch index
# 514    circular citation area radius r   circular citat area radiu r
# 515                                cis                            ci
# 516                           citation                         citat
# 517            citation acceleration a               citat acceler a
# 518                  citation accuracy                citat accuraci
# 519                       citation age                     citat age
# 520                       citation age                     citat age
# 521                  citation analysis                 citat analysi
# 522                  citation analysis                 citat analysi
# 523               citation base impact             citat base impact
# 524                  citation behavior                citat behavior
# 525                      citation bias                     citat bia
# 526            citation categorisation               citat categoris
# 527                   citation classic                 citat classic
# 528                   citation classic                 citat classic
# 529                   citation context                 citat context
# 530    citation context classification         citat context classif
# 531                  citation contexts                 citat context
# 532                citation contextual                citat contextu
# 533                     citation count                   citat count
# 534                     citation count                   citat count
# 535                  citation database                 citat databas
# 536                  citation database                 citat databas
# 537                   citation density                 citat densiti
# 538              citation distribution               citat distribut
# 539        citation distribution model         citat distribut model
# 540              citation distribution               citat distribut
# 541                     citation error                   citat error
# 542       citation family relationship     citat famili relationship
# 543                 citation frequency                citat frequenc
# 544                citation generation                   citat gener
# 545         citation genetic genealogy          citat genet genealog
# 546                     citation graph                   citat graph
# 547                   citation history                 citat histori
# 548                    citation impact                  citat impact
# 549         citation impact prediction          citat impact predict
# 550                 citation increment               citat increment
# 551                     citation index                   citat index
# 552            citation index analysis           citat index analysi
# 553         citation index publication            citat index public
# 554              citation index system            citat index system
# 555                   citation indexes                   citat index
# 556                  citation indexing                   citat index
# 557                 citation indicator                   citat indic
# 558                     citation index                   citat index
# 559                   citation linking                    citat link

# %% [markdown]
# ## edge change from id to label

# %%
df_edge = df_edges[0]

# %%
df_new_edges = []
def replace_id_to_label(df_new_label, df_edge):
    df_new_edge = pd.DataFrame(columns=['source', 'target', 'weight'])
    for i in range(len(df_edge)):
        label_id_source = int(df_edge['source'].loc[i])
        label_id_target = int(df_edge['target'].loc[i])
        source_label_STEM = df_new_label[df_new_label['id']==label_id_source]['STEM'].values[0]
        target_label_STEM = df_new_label[df_new_label['id']==label_id_target]['STEM'].values[0]
        df_new_edge.at[i, 'source'] = source_label_STEM
        df_new_edge.at[i, 'target'] = target_label_STEM
        df_new_edge.at[i, 'weight'] = df_edge['weight'].loc[i]
    
    return df_new_edge

# %%
df_lemma_nodes = []
df_new_edges = []
for i in range(len(df_nodes)):
    df_new_label = label_lemma(df_nodes[i])
    df_new_edge = replace_id_to_label(df_new_label, df_edges[i])
    
    df_lemma_nodes.append(df_new_label)
    df_new_edges.append(df_new_edge)

# %%
files
# Out:
# ['jasist_2010-2015',
#  'jasist_2010-2016',
#  'jasist_2010-2017',
#  'jasist_2010-2018',
#  'jasist_2010-2019']

# %%
output_path = os.getcwd()+"\\output\\lemma files\\jasist_cooccur\\"
for i, v in enumerate(files):
    df_lemma_nodes[i].to_pickle(output_path+"{}_lemma_nodes.pkl".format(v))
    df_new_edges[i].to_pickle(output_path+"{}_lemma_edges.pkl".format(v))
